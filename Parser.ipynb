# %%
import pandas as pd
from pyhanlp import *

# %%
""" Extract decision and create decision.csv with decision and pid """
# pollution_df = pd.read_csv("pollution_data/pollution_original_parsed.csv")
# print(pollution_df['decision'])
# decision_df = pollution_df[['pid', 'case_number_id', 'title', 'decision']]
# print(decision_df[:6])
# decision_df.to_csv("decision.csv", encoding='utf-8-sig')

# %%
""" Extract name information from pid; update decision.csv"""
# decision_df = pd.read_csv("./decision_origin.csv")
# pollution_df = pd.read_csv("pollution_data/pollution.csv")
# name_lst = []
# for index, row in decision_df.iterrows():
#     pid = row['pid']
#     k = pollution_df.loc[(pollution_df['Id'] == pid) & (pollution_df['Role'].isin(["Appellant", "Defendant"]))]
#     name_lst.append(k['Name'].values)
# # name_series = pd.Series(name_lst)
# decision_df['name'] = name_lst
# decision_df = decision_df.reindex(columns=["pid", "case_number_id", "title", "name", "decision"])
# decision_df.to_csv("decision.csv", encoding='utf-8-sig')

# %%
""" Fixing missing name in "name" column; update decision.csv"""
# def find_name(s):
#     name = []
#     if "等" in s:
#         for i in range(len(s)):
#             if s[i] == "等":
#                 name.append(s[:i])
#     elif "犯" in s:
#         for i in range(len(s)):
#             if s[i] == "犯" and s[i+1] == "污":
#                 name.append(s[:i])
#     else:
#         for i in range(len(s)):
#             if s[i] == "污" and s[i+1] == "染":
#                 name.append(s[:i])
#     return name
#
# decision_df = pd.read_csv("./decision.csv")
# for index, row in decision_df.iterrows():
#     if len(row["name"]) < 3:
#         name = find_name(row["title"])
#         #print(row["name"])
#         decision_df.at[index,'name'] = name
# decision_df.to_csv("decision.csv", encoding='utf-8-sig')

# %%
""" NLP Stuff"""
# title = decision_df['title']
# print(title)
# for i in title:
#     s_hanlp = HanLP.segment(i)
#     print(s_hanlp)
sentence1 = '[" 一、被告单位瑞安宝源化工有限公司犯污染环境罪，判处罚金人民币8000000元。罚金限本判决生效之日起十日内缴纳。", "二、被告人林文弟犯污染环境罪，判处有期徒刑四年六个月，并处罚金人民币200000元。罚金限本判决生效之日起十日内缴纳。", "（刑期从判决执行之日起计算。判决执行以前先行羁押的，羁押一日折抵刑期一日。即自2014年11月19日起至2019年5月18日止）。", "三、被告人陈乐平犯污染环境罪，判处有期徒刑三年，并处罚金人民币100000元。罚金限本判决生效之日起十日内缴纳。", "（刑期从判决执行之日起计算。判决执行以前先行羁押的，羁押一日折抵刑期一日。即自2014年11月18日起至2017年11月17日止）。", "四、被告人戴锡全犯污染环境罪，判处有期徒刑四年，并处罚金人民币200000元。罚金限本判决生效之日起十日内缴纳。", "（刑期从判决执行之日起计算。判决执行以前先行羁押的，羁押一日折抵刑期一日。即自2015年3月17日起至2019年3月16日止）。", "五、被告人尚某犯污染环境罪，判处有期徒刑二年，缓刑三年，并处罚金人民币50000元。罚金限本判决生效之日起十日内缴纳。", "（缓刑考验期限从判决确定之日起计算）。", "六、被告人吴某犯污染环境罪，判处有期徒刑二年，缓刑三年，并处罚金人民币50000元。罚金限本判决生效之日起十日内缴纳。", "（缓刑考验期限从判决确定之日起计算）。", "七、被告人李某甲犯污染环境罪，判处有期徒刑二年，缓刑三年，并处罚金人民币50000元。罚金限本判决生效之日起十日内缴纳。", "（缓刑考验期限从判决确定之日起计算）。", "八、被告人储某犯污染环境罪，判处有期徒刑二年，缓刑三年，并处罚金人民币50000元。罚金限本判决生效之日起十日内缴纳。", "（缓刑考验期限从判决确定之日起计算）。", "九、被告人黄某甲犯污染环境罪，判处有期徒刑二年，缓刑三年，并处罚金人民币100000元。罚金限本判决生效之日起十日内缴纳。", "（缓刑考验期限从判决确定之日起计算）。", "如不服本判决，可在接到判决书的第二日起十日内，通过本院或直接向浙江省温州市中级人民法院提出上诉。书面上诉的，应当提交上诉状正本一份、副本二份。"]'
sentence2 = '[" 被告人宋某犯污染环境罪，判处有期徒刑一年六个月，缓刑二年六个月，并处罚金人民币五万元。", "缓刑考验期限，从判决确定之日起计算。", "被告人蔚某犯污染环境罪，判处有期徒刑一年，缓刑二年，并处罚金人民币二万元。", "缓刑考验期限，从判决确定之日起计算。", "如不服本判决，可在接到判决书的第二日起十日内，通过本院或直接向吕梁市中级人民法院提出上诉，书面上诉的，应当提交上诉状正本一份，副本五份。"]'
sentence3 = '[" 一、维持邹平县人民法院（2017）鲁1626刑初253号刑事判决第一项及第二项中对上诉人（原审被告人）李现民、原审被告人张芝军、王玲、张芝广犯污染环境罪的定罪处刑部分。", "二、撤销邹平县人民法院（2017）鲁1626刑初253号刑事判决第二项中对上诉人（原审被告人）李现民的合并执行部分。", "三、上诉人（原审被告人）李现民犯污染环境罪，判处有期徒刑三年，并处罚金人民币六万元，与前犯危险驾驶罪所判处拘役六个月并罚，决定执行有期徒刑三年，并处罚金人民币六万元。", "（刑期从判决执行之日起计算。判决执行以前先行羁押的，羁押一日折抵刑期一日，即自2017年3月10日起至2020年3月9日止。罚金于本判决生效后十日内缴纳。）", "本判决为终审判决。"]'
w = sentence1.split(",")[0]
s_hanlp_w = HanLP.segment(w)
print(s_hanlp_w)
#print(type(s_hanlp_k))

# for i in range(3):
#     name.append(s_hanlp_k.get(i).word)

print("done")
# print(find_name(w), " ", find_name(k), " ", find_name(v))
# print(str(s_hanlp_w.get(5).nature))
# print(str(s_hanlp_w.get(5).nature) == "n")
# Out:
# [["/w,  /w, 一/m, 、/w, 被告/n, 单位/n, 瑞安/nrf, 宝源/nz, 化工/n, 有限公司/nis, 犯/v, 污染/vn, 环境/n, 罪/n, ，/w, 判处/v, 罚金/n, 人民币/n, 8000000/m, 元/q, 。/w, 罚金/n, 限/v, 本/rz, 判决/vn, 生效/vi, 之日起/ns, 十/m, 日内/t, 缴纳/v, 。/w, "/w]
# done

# %%
""" Extract court decisions from decision column"""
# helper function
def extract_penalties(sentence, name, i, decision_dic, nature, find_lst):
    k = i + 1
    p = []
    while k < len(sentence):
        if str(sentence.get(k).nature) != nature:
            p.append(sentence.get(k).word)
        else:
            break
        k += 1
    decision_dic[name] = "".join(p)
    find_lst[name] = False
    return find_lst, decision_dic
# function that find all penalties from a single sentence
def clean_penalties(sentence):
    def find_penalties(decision):
        decision_dic = {}
        if ("被告" in decision):
            sentence = HanLP.segment(decision)
            find_lst = {"被告人":True, "单位":True, "有期徒刑":True, "罚金":True, 
                        "缓刑":True, "羁押":True, "拘役":True}
            for i in range(len(sentence)):
                # ignore special words (维持，驳回，撤销)
                if (sentence.get(i).word == "单位") and (find_lst["单位"]):
                    find_lst, decision_dic = extract_penalties(sentence, "被告单位", i, decision_dic, "v", find_lst)
                if (sentence.get(i).word == "被告人") and (find_lst["被告人"]):
                    find_lst, decision_dic = extract_penalties(sentence, "被告人", i, decision_dic, "v", find_lst)
                if (sentence.get(i).word == "有期徒刑") and (find_lst["有期徒刑"]):
                    find_lst, decision_dic = extract_penalties(sentence, "有期徒刑", i, decision_dic, "w", find_lst)
                if (sentence.get(i).word == "罚金") and (find_lst["罚金"]):
                    find_lst, decision_dic = extract_penalties(sentence, "罚金", i, decision_dic, "w", find_lst)
                if (sentence.get(i).word == "处罚金") and (find_lst["罚金"]):
                    find_lst, decision_dic = extract_penalties(sentence, "处罚金", i, decision_dic, "w", find_lst)
                if (sentence.get(i).word == "缓刑") and (find_lst["缓刑"]):
                    find_lst, decision_dic = extract_penalties(sentence, "缓刑", i, decision_dic, "w", find_lst)    
                if (sentence.get(i).word == "羁押") and (find_lst["羁押"]):
                    find_lst, decision_dic = extract_penalties(sentence, "羁押", i, decision_dic, "w", find_lst)    
                if (sentence.get(i).word == "拘役") and (find_lst["拘役"]):
                    find_lst, decision_dic = extract_penalties(sentence, "拘役", i, decision_dic, "w", find_lst)    
        return decision_dic
    
    sentence_lst = sentence.split("。")
    penalties = []
    if ("维持" in sentence) or ("驳回" in sentence) or ("撤销" in sentence):
        return {}
    for i in sentence_lst:
        p = find_penalties(i)
        if len(p) > 1:
            penalties.append(p)
    return penalties
penalties = clean_penalties(sentence1)
penalties
# Out:
# [{'被告单位': '瑞安宝源化工有限公司', '罚金': '人民币8000000元'},
#  {'被告人': '林文弟', '有期徒刑': '四年六个月', '罚金': '人民币200000元'},
#  {'被告人': '陈乐平', '有期徒刑': '三年', '罚金': '人民币100000元'},
#  {'被告人': '戴锡全', '有期徒刑': '四年', '罚金': '人民币200000元'},
#  {'被告人': '尚某', '有期徒刑': '二年', '缓刑': '三年', '罚金': '人民币50000元'},
#  {'被告人': '吴某', '有期徒刑': '二年', '缓刑': '三年', '罚金': '人民币50000元'},
#  {'被告人': '李某甲', '有期徒刑': '二年', '缓刑': '三年', '罚金': '人民币50000元'},
#  {'被告人': '储某', '有期徒刑': '二年', '缓刑': '三年', '罚金': '人民币50000元'},
#  {'被告人': '黄某甲', '有期徒刑': '二年', '缓刑': '三年', '罚金': '人民币100000元'}]

# %%
# TODO: Handle the case where “撤销”

# %%
decision_df = pd.read_csv("./decision.csv")

# %%
decision_df.shape
# Out:
# (6107, 7)

# %%
# find the number of unique cases in the dataframe
def shorten(text):
    if len(text) > 300:
        return text[:300]
    else:
        return text
#pollution_df["decision"].apply(shorten)

len_data = []
unique_case = []
for index, row in decision_df.iterrows():
    l = len(clean_penalties(shorten(row['decision'])))
    if l == 0:
        unique_case.append(index)
    len_data.append(l)

# %%
unique_case
# Out:
# [12,
#  28,
#  37,
#  50,
#  52,
#  57,
#  115,
#  122,
#  138,
#  148,
#  176,
#  204,
#  224,
#  230,
#  231,
#  235,
#  240,
#  259,
#  282,
#  283,
#  286,
#  296,
#  322,
#  326,
#  334,
#  336,
#  352,
#  353,
#  403,
#  439,
#  462,
#  486,
#  488,
#  505,
#  506,
#  546,
#  554,
#  567,
#  597,
#  624,
#  659,
#  662,
#  686,
#  703,
#  709,
#  735,
#  762,
#  767,
#  771,
#  772,
#  798,
#  801,
#  807,
#  834,
#  838,
#  857,
#  869,
#  874,
#  881,
#  910,
#  928,
#  962,
#  984,
#  999,
#  1024,
#  1040,
#  1045,
#  1070,
#  1100,
#  1135,
#  1155,
#  1158,
#  1169,
#  1207,
#  1233,
#  1249,
#  1276,
#  1297,
#  1298,
#  1326,
#  1328,
#  1354,
#  1374,
#  1376,
#  1389,
#  1400,
#  1432,
#  1437,
#  1511,
#  1523,
#  1536,
#  1540,
#  1543,
#  1553,
#  1584,
#  1612,
#  1614,
#  1618,
#  1621,
#  1634,
#  1648,
#  1661,
#  1667,
#  1693,
#  1695,
#  1717,
#  1746,
#  1753,
#  1758,
#  1761,
#  1763,
#  1781,
#  1782,
#  1788,
#  1808,
#  1812,
#  1820,
#  1873,
#  1904,
#  1905,
#  1915,
#  1919,
#  1982,
#  1985,
#  1994,
#  1996,
#  2012,
#  2035,
#  2039,
#  2045,
#  2072,
#  2080,
#  2089,
#  2110,
#  2122,
#  2136,
#  2149,
#  2171,
#  2184,
#  2212,
#  2247,
#  2250,
#  2276,
#  2279,
#  2340,
#  2351,
#  2352,
#  2362,
#  2366,
#  2407,
#  2421,
#  2422,
#  2428,
#  2444,
#  2446,
#  2465,
#  2482,
#  2483,
#  2484,
#  2491,
#  2508,
#  2536,
#  2544,
#  2561,
#  2564,
#  2575,
#  2591,
#  2603,
#  2612,
#  2627,
#  2630,
#  2659,
#  2672,
#  2673,
#  2680,
#  2691,
#  2719,
#  2722,
#  2726,
#  2727,
#  2743,
#  2765,
#  2776,
#  2779,
#  2780,
#  2781,
#  2791,
#  2806,
#  2826,
#  2839,
#  2850,
#  2916,
#  2950,
#  3041,
#  3055,
#  3110,
#  3147,
#  3168,
#  3169,
#  3190,
#  3224,
#  3257,
#  3262,
#  3263,
#  3285,
#  3288,
#  3292,
#  3321,
#  3327,
#  3337,
#  3351,
#  3371,
#  3418,
#  3430,
#  3432,
#  3443,
#  3487,
#  3505,
#  3520,
#  3541,
#  3560,
#  3563,
#  3592,
#  3600,
#  3602,
#  3629,
#  3681,
#  3760,
#  3780,
#  3786,
#  3795,
#  3822,
#  3831,
#  3834,
#  3838,
#  3893,
#  3897,
#  3906,
#  3907,
#  3923,
#  3991,
#  4011,
#  4014,
#  4032,
#  4033,
#  4037,
#  4043,
#  4053,
#  4056,
#  4060,
#  4076,
#  4115,
#  4127,
#  4190,
#  4216,
#  4255,
#  4266,
#  4288,
#  4319,
#  4320,
#  4341,
#  4344,
#  4346,
#  4350,
#  4354,
#  4382,
#  4398,
#  4400,
#  4415,
#  4479,
#  4498,
#  4529,
#  4546,
#  4553,
#  4604,
#  4625,
#  4639,
#  4677,
#  4681,
#  4709,
#  4751,
#  4770,
#  4800,
#  4849,
#  4852,
#  4910,
#  4934,
#  4940,
#  4991,
#  5000,
#  5006,
#  5013,
#  5021,
#  5022,
#  5065,
#  5070,
#  5087,
#  5088,
#  5177,
#  5182,
#  5187,
#  5221,
#  5232,
#  5285,
#  5317,
#  5331,
#  5343,
#  5345,
#  5415,
#  5430,
#  5494,
#  5511,
#  5540,
#  5556,
#  5559,
#  5581,
#  5631,
#  5641,
#  5652,
#  5680,
#  5688,
#  5694,
#  5696,
#  5697,
#  5702,
#  5734,
#  5751,
#  5792,
#  5804,
#  5812,
#  5823,
#  5854,
#  5867,
#  5873,
#  5880,
#  5882,
#  5921,
#  5923,
#  5947,
#  5948,
#  5950,
#  5965,
#  5979,
#  6021,
#  6033,
#  6044,
#  6059,
#  6066,
#  6074,
#  6089,
#  6103]

# %%
len(unique_case)
# Out:
# 351

# %%
pollution_df = pd.read_csv("pollution_data/pollution_original_parsed_utf-8.csv")
pollution_df
# Out:
#            pid       court     std_court   decision_date converted_date  \
# 0     20234731  深圳市宝安区人民法院    深圳市宝安区人民法院      二〇一五年八月十一日     2015-08-11
# 二月九日     2014-02-09
# 2     28511110     晋州市人民法院       晋州市人民法院     二〇一七年九月二十七日     2017-09-27
# 3     18206959     三门县人民法院       三门县人民法院    二〇一五年十一月二十七日     2015-11-27
# 4     29337046  龙岩市新罗区人民法院    龙岩市新罗区人民法院     二〇一六年三月二十五日     2016-03-25
# 5     28286594     霸州市人民法院       霸州市人民法院    二〇一四年十二月二十九日     2014-12-29
# 6     18146262  湖州市南浔区人民法院    湖州市南浔区人民法院       二〇一五年八月五日     2015-08-05
# 7     27640642     永清县人民法院       永清县人民法院       二〇一四年四月八日     2014-04-08
# 8     17895583     临海市人民法院       临海市人民法院     二〇一六年八月三十一日     2016-08-31
# 9     18445053     德清县人民法院       德清县人民法院     二〇一六年二月二十五日     2016-02-25
# 10    17078470     瑞安市人民法院       瑞安市人民法院       二〇一五年十月十日     2015-10-10
# 11    23843967     汾阳市人民法院       汾阳市人民法院       二〇一五年二月十日     2015-02-10
# 12    17529731   温州市中级人民法院  浙江省温州市中级人民法院     二〇一六年一月二十八日     2016-01-28
# 13    27118957     涞源县人民法院       涞源县人民法院    二〇一六年十二月二十八日     2016-12-28
# 14    22513502  揭阳市榕城区人民法院    揭阳市榕城区人民法院     二〇一六年十一月十五日     2016-11-15
# 15    28516213     晋州市人民法院       晋州市人民法院      二〇一八年三月十二日     2018-03-12
# 16    18466982     乐清市人民法院       乐清市人民法院       二〇一八年二月五日     2018-02-05
# 17    14556078     常熟市人民法院       常熟市人民法院      二〇一六年十二月五日     2016-12-05
# 18    21625900  广州市增城区人民法院       增城市人民法院      二〇一六年八月十一日     2016-08-11
# 19    12946228     江阴市人民法院       江阴市人民法院      二〇一六年九月十八日     2016-09-18
# 20    28747161     永清县人民法院       永清县人民法院     二〇一七年四月二十五日     2017-04-25
# 21    17773036     武义县人民法院       武义县人民法院     二〇一六年七月二十一日     2016-07-21
# 22    22295377     海丰县人民法院       海丰县人民法院      二〇一八年六月十九日     2018-06-19
# 23    17429947     海盐县人民法院       海盐县人民法院     二〇一四年五月二十三日     2014-05-23
# 24    16700769  温州市瓯海区人民法院    温州市瓯海区人民法院       二〇一六年四月一日     2016-04-01
# 25    15891303  台州市路桥区人民法院    台州市路桥区人民法院     二〇一六年三月二十四日     2016-03-24
# 26    28840161     大名县人民法院       大名县人民法院     二〇一八年五月二十五日     2018-05-25
# 27    27230371     博野县人民法院       博野县人民法院       二〇一五年五月七日     2015-05-07
# 28    30664338     将乐县人民法院       将乐县人民法院       二〇一八年一月九日     2018-01-09
# 29    10326318     宁津县人民法院       宁津县人民法院     二〇一六年十一月十八日     2016-11-18
# ...        ...         ...           ...             ...            ...
# 6077  18681076     永康市人民法院       永康市人民法院     二〇一七年十一月十五日     2017-11-15
# 6078  17163074     兰溪市人民法院       兰溪市人民法院     二〇一五年十二月十五日     2015-12-15
# 6079  28228360  承德市双滦区人民法院    承德市双滦区人民法院     二〇一五年十一月十二日     2015-11-12
# 6080  15792816     浦江县人民法院       浦江县人民法院       二〇一六年七月七日     2016-07-07
# 6081  42206468     北辰区人民法院    天津市北辰区人民法院      二〇一四年七月二十日     2014-07-20
# 6082   8334333      和县人民法院        和县人民法院     二〇一七年十一月三十日     2017-11-30
# 6083  21616000     普宁市人民法院       普宁市人民法院     二〇一六年九月二十六日     2016-09-26
# 6084  21766941   东莞市第一人民法院     东莞市第一人民法院  二〇一七二〇一七年十二月八日     2017-12-08
# 6085  18144545  温州市瓯海区人民法院    温州市瓯海区人民法院      二〇一六年十二月一日     2016-12-01
# 6086  30835214     茶陵县人民法院       茶陵县人民法院       二〇一六年十二月日            NaN
# 6087  22198427  潮州市潮安区人民法院    潮州市潮安区人民法院       二〇一七年八月八日     2017-08-08
# 6088   5535274    上海铁路运输法院      上海铁路运输法院      二〇一七年三月十五日     2017-03-15
# 6089  16221127   温州市中级人民法院  浙江省温州市中级人民法院     二〇一七年二月二十八日     2017-02-28
# 6090  39633937     渝北区人民法院    重庆市渝北区人民法院      二〇一八年三月十二日     2018-03-12
# 6091  11324310     武城县人民法院       武城县人民法院      二〇一五年七月十七日     2015-07-17
# 6092  18472314     苍南县人民法院       苍南县人民法院     二〇一七年十一月十四日     2017-11-14
# 6093  27236373     晋州市人民法院       晋州市人民法院      二〇一六年四月十九日     2016-04-19
# 6094  27230581     博野县人民法院       博野县人民法院       二〇一六年五月六日     2016-05-06
# 6095  27530137     黄骅市人民法院       黄骅市人民法院      二〇一四年四月十六日     2014-04-16
# 6096  17168484  绍兴市上虞区人民法院    绍兴市上虞区人民法院      二〇一五年十二月八日     2015-12-08
# 6097  16478943     桐乡市人民法院       桐乡市人民法院       二〇一四年五月七日     2014-05-07
# 6098  28789241     玉田县人民法院       玉田县人民法院      二〇一七年十二月四日     2017-12-04
# 6099  10193238     昌乐县人民法院       昌乐县人民法院       二〇一五年六月三日     2015-06-03
# 6100  16740982     义乌市人民法院       义乌市人民法院     二〇一四年十一月十四日     2014-11-14
# 6101  18147803  绍兴市越城区人民法院    绍兴市越城区人民法院     二〇一四年十一月二十日     2014-11-20
# 6102  21878799  汕头市潮南区人民法院    汕头市潮南区人民法院     二〇一八年二月二十三日     2018-02-23
# 6103  16620699   金华市中级人民法院  浙江省金华市中级人民法院    二〇一四年十一月二十九日     2014-11-29
# 6104   4093325  银川市西夏区人民法院    银川市西夏区人民法院     二〇一五年九月二十一日     2015-09-21
# 6105  28023218      献县人民法院        献县人民法院      二〇一六年六月十六日     2016-06-16
# 6106  15289362     溧阳市人民法院       溧阳市人民法院       二〇一七年七月七日     2017-07-07
#
#        start_date converted_start  year_id case_number_id  \
# 0      2015年7月29日      2015-07-29   2015.0           1193
# 1     2014年11月11日      2014-11-11   2014.0           3389
# 2       2017年9月5日      2017-09-05   2017.0            197
# 3      2015年3月23日      2015-03-23   2015.0             99
# 4      2015年9月24日      2015-09-24   2015.0            791
# 5     2014年10月29日      2014-10-29   2014.0            474
# 6      2015年7月17日      2015-07-17   2015.0            388
# 7       2014年1月3日      2014-01-03   2014.0             26
# 8       2016年7月8日      2016-07-08   2016.0            701
# 9     2015年11月26日      2015-11-26   2015.0            615
# 10     2015年7月24日      2015-07-24   2015.0           1329
# 11    2014年12月15日      2014-12-15   2014.0            243
# 12            NaN             NaN   2015.0           1904
# 13     2016年11月9日      2016-11-09   2016.0            133
# 14    2016年10月26日      2016-10-26   2016.0            401
# 15            NaN             NaN   2018.0              8
# 16     2018年1月17日      2018-01-17   2018.0            146
# 17    2016年11月11日      2016-11-11   2016.0           1680
# 18     2016年6月12日      2016-06-12   2016.0            545
# 19     2016年8月23日      2016-08-23   2016.0           1749
# 20      2017年4月1日      2017-04-01   2017.0             65
# 21      2016年7月8日      2016-07-08   2016.0            327
# 22      2018年6月5日      2018-06-05   2018.0            299
# 23            NaN             NaN   2014.0            160
# 24     2016年3月24日      2016-03-24   2016.0            255
# 25     2016年3月16日      2016-03-16   2016.0            245
# 26            NaN             NaN   2018.0             80
# 27     2015年2月13日      2015-02-13   2015.0             34
# 28      2018年1月3日      2018-01-03   2018.0              2
# 29    2016年10月25日      2016-10-25   2016.0             74
# ...           ...             ...      ...            ...
# 6077   2017年11月6日      2017-11-06   2017.0           1268
# 6078  2015年10月27日      2015-10-27   2015.0            582
# 6079   2015年8月26日      2015-08-26   2015.0             64
# 6080   2016年6月24日      2016-06-24   2016.0            579
# 6081   2014年7月11日      2014-07-11   2014.0           0279
# 6082  2017年10月12日      2017-10-12   2017.0            241
# 6083   2016年5月26日      2016-05-26   2016.0            393
# 6084  2017年11月14日      2017-11-14   2017.0           2818
# 6085   2016年9月30日      2016-09-30   2016.0            894
# 6086  2016年11月16日      2016-11-16   2016.0            215
# 6087   2017年7月27日      2017-07-27   2017.0            349
# 6088    2017年3月1日      2017-03-01   2017.0             54
# 6089          NaN             NaN   2017.0            277
# 6090   2018年2月23日      2018-02-23   2018.0            233
# 6091    2015年6月4日      2015-06-04   2015.0             45
# 6092   2017年11月8日      2017-11-08   2017.0           1180
# 6093   2016年1月19日      2016-01-19   2016.0             34
# 6094   2016年2月16日      2016-02-16   2016.0             39
# 6095  2013年12月23日      2013-12-23   2014.0             18
# 6096  2015年11月30日      2015-11-30   2015.0           1099
# 6097   2014年4月23日      2014-04-23   2014.0            378
# 6098   2017年5月22日      2017-05-22   2017.0            220
# 6099   2015年2月12日      2015-02-12   2015.0             77
# 6100    2014年8月7日      2014-08-07   2014.0           1892
# 6101   2014年11月7日      2014-11-07   2014.0           1301
# 6102   2018年1月19日      2018-01-19   2018.0             88
# 6103          NaN             NaN   2014.0            346
# 6104   2015年9月15日      2015-09-15   2015.0            224
# 6105   2016年4月14日      2016-04-14   2016.0            112
# 6106          NaN             NaN   2017.0            367
#
#                                        title  ...  \
# 0                            王在堂污染环境罪一审刑事判决书  ...
# 1                             侯某某环境污染一审刑事判决书  ...
# 2                            陈某犯污染环境罪一审刑事判决书  ...
# 3                         赵某、蔡某犯污染环境罪一审刑事判决书  ...
# 4                      林汉强、陈某甲等犯污染环境罪一审刑事判决书  ...
# 5                             李某污染环境罪一审刑事判决书  ...
# 6                       黄某甲、黄某乙犯污染环境罪一审刑事判决书  ...
# 7                            陈某甲污染环境罪一审刑事判决书  ...
# 8                        梁某、朱某甲犯污染环境罪一审刑事判决书  ...
# 9                        曾阳、张海修等污染环境罪一审刑事判决书  ...
# 10              瑞安宝源化工有限公司、林文弟等犯污染环境罪一审刑事判决书  ...
# 11                        宋某、蔚某犯污染环境罪一审刑事判决书  ...
# 12                           徐某犯污染环境罪二审刑事判决书  ...
# 13                           王甲犯污染环境罪一审刑事判决书  ...
# 14                         周雄钦周某某污染环境一审刑事判决书  ...
# 15                        李某、贾某犯污染环境罪一审刑事判决书  ...
# 16              乐清市永联电工合金有限公司、韩梅涛污染环境一审刑事判决书  ...
# 17                           周某犯污染环境罪一审刑事判决书  ...
# 18    广州市冠铭五金制品有限公司与刘永志污染环境罪2016刑初545一审刑事判决书  ...
# 19                          王品妹犯污染环境罪一审刑事判决书  ...
# 20                          李某、周某污染环境一审刑事判决书  ...
# 21                          罗某甲犯污染环境罪一审刑事判决书  ...
# 22                            陈向忠污染环境一审刑事判决书  ...
# 23                         蒉某、陆某污染环境罪一审刑事判决书  ...
# 24                           陈某犯污染环境罪一审刑事判决书  ...
# 25                           成某犯污染环境罪一审刑事判决书  ...
# 26                            乔某某污染环境一审刑事判决书  ...
# 27                          李某甲犯污染环境罪一审刑事判决书  ...
# 28                            廖建伟污染环境一审刑事判决书  ...
# 29                           李某犯污染环境罪一审刑事判决书  ...
# ...                                      ...  ...
# 6077                    邹洪生、胡梦江等污染环境罪一审刑事判决书  ...
# 6078                     陈某、童某等犯污染环境罪一审刑事判决书  ...
# 6079                      被告人王某某污染环境罪一审刑事判决书  ...
# 6080                    陈某甲、陈某乙犯污染环境罪一审刑事判决书  ...
# 6081                          徐XX污染环境一审刑事判决书  ...
# 6082                          景某污染环境罪一审刑事判决书  ...
# 6083                           李某污染环境一审刑事判决书  ...
# 6084                          何秀兰污染环境一审刑事判决书  ...
# 6085                     丁洪友、林金生污染环境罪一审刑事判决书  ...
# 6086                         蒋茂文污染环境罪一审刑事判决书  ...
# 6087                      郭泽喜、李明和污染环境一审刑事判决书  ...
# 6088                          赵某某污染环境一审刑事判决书  ...
# 6089                      许妙云、胡忠考污染环境二审刑事裁定书  ...
# 6090                          唐仕才污染环境一审刑事判决书  ...
# 6091                     被告人崔凤杰犯污染环境罪一审刑事判决书  ...
# 6092                         蔡启梨污染环境罪一审刑事判决书  ...
# 6093                         马某犯污染环境罪一审刑事判决书  ...
# 6094                           吴某污染环境一审刑事判决书  ...
# 6095                          张某某污染环境一审刑事判决书  ...
# 6096                      沈某、熊某犯污染环境罪一审刑事判决书  ...
# 6097                          严某污染环境罪一审刑事判决书  ...
# 6098              河北省玉田县人民检察院与李某污染环境罪一审刑事判决书  ...
# 6099                     秦某、傅某甲犯污染环境罪一审刑事判决书  ...
# 6100                         徐某甲污染环境罪一审刑事判决书  ...
# 6101                        刘某甲犯污染环境罪一审刑事判决书  ...
# 6102                          庄某江污染环境一审刑事判决书  ...
# 6103                     夏某甲、夏某乙污染环境罪二审刑事判决书  ...
# 6104                         张某某污染环境罪一审刑事判决书  ...
# 6105                           姚某污染环境一审刑事判决书  ...
# 6106                      张春、黄耀平污染环境罪一审刑事判决书  ...
#
#                                            laws_statute  \
# 0              {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款}
# 1     {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十三条,《中华人民共和国刑...
# 2     {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条,《中华人民共和国刑...
# 3     {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 4     {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十一条,《中华人民共和国刑...
# 5     {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第一款,《中华人民共...
# 6     {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 7     {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款,《中华人民共...
# 8     {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 9     {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 10    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第三百四十六条,《中华人民共和...
# 11    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第五十二条,《中华人民共和国刑...
# 12    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第一款,《中华人民共...
# 13    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款,《最高人民法...
# 14    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第一款,《中华人民共...
# 15    {《中华人民共和国刑法》第三百三十八条,《关于办理环境污染刑事案件适用法律若干问题的解释》第一条}
# 16    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第三十条,《中华人民共和国刑法...
# 17    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第一款,《最高人民法...
# 18    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第三百四十六条,《中华人民共和...
# 19    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款,《中华人民共...
# 20    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款,《中华人民共...
# 21    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第一款,《中华人民共...
# 22    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款,《中华人民共...
# 23    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 24             {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款}
# 25    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 26    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第五十二条,《中华人民共和国刑...
# 27                                 {《中华人民共和国刑法》第三百三十八条}
# 28    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款,《中华人民共...
# 29    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十二条,《中华人民共和国刑...
# ...                                                 ...
# 6077  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 6078  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 6079  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款,《中华人民共...
# 6080  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 6081  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第五十二条,《中华人民共和国刑...
# 6082  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第十七条,《中华人民共和国刑法...
# 6083  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第五十三条,《关于办理环境污染...
# 6084  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款,《中华人民共...
# 6085  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第三百四十六条,《中华人民共和...
# 6086  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款,《中华人民共...
# 6087  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 6088  {《中华人民共和国刑法》第十二条第一款,《中华人民共和国刑法》第三百三十八条,《中华人民共和...
# 6089  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 6090  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款,《中华人民共...
# 6091  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第一款,《中华人民共...
# 6092  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 6093  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条,《中华人民共和国刑...
# 6094  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第一款,《中华人民共...
# 6095  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条,《关于办理环境污染...
# 6096  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第一款,《中华人民共...
# 6097           {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款}
# 6098  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条,《中华人民共和国刑...
# 6099              {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第五十二条}
# 6100  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款,《中华人民共...
# 6101  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款,《最高人民法...
# 6102  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 6103  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 6104                               {《中华人民共和国刑法》第三百三十八条}
# 6105  {《中华人民共和国刑法》第三百三十八条,《最高人民法院、最高人民检察院关于办理环境污染刑事案...
# 6106  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
#
#                                               laws_full  \
# 0              {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款}
# 1     {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十三条,《中华人民共和国刑...
# 2     {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条,《中华人民共和国刑...
# 3     {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 4     {《废弃电器电子产品回收处理管理条例》第十二条第二款,《中华人民共和国刑法》第三百三十八条,...
# 5     {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第一款,《中华人民共...
# 6     {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 7     {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款,《中华人民共...
# 8     {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 9     {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 10    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第三百四十六条,《中华人民共和...
# 11    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第三百三十八条,《中华人民共和...
# 12    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第一款,《中华人民共...
# 13    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第三百三十八条,《中华人民共和...
# 14    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第一款,《中华人民共...
# 15    {《中华人民共和国刑法》第三百三十八条,《关于办理环境污染刑事案件适用法律若干问题的解释》第一条}
# 16    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第三十条,《中华人民共和国刑法...
# 17    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第一款,《中华人民共...
# 18    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款,《中华人民共...
# 19    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款,《中华人民共...
# 20    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第三百三十八条,《中华人民共和...
# 21    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第一款,《中华人民共...
# 22    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第三百三十八条,《中华人民共和...
# 23    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 24             {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款}
# 25    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 26    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第三百三十八条,《中华人民共和...
# 27              {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第三百三十八条}
# 28    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款,《中华人民共...
# 29    {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十二条,《中华人民共和国刑...
# ...                                                 ...
# 6077  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 6078  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 6079  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑事诉讼法》第一百七十二条,《中华人...
# 6080  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 6081  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第五十二条,《中华人民共和国刑...
# 6082  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第三百三十八条,《中华人民共和...
# 6083  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第三百三十八条,《中华人民共和...
# 6084  {《中华人民共和国刑事诉讼法》第一百五十八条第二款,《关于适用〈中华人民共和国刑事诉讼法〉的...
# 6085  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第三百四十六条,《中华人民共和...
# 6086  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款,《中华人民共...
# 6087  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 6088  {《中华人民共和国刑法》第十二条第一款,《中华人民共和国刑法》第三百三十八条,《中华人民共和...
# 6089  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 6090  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款,《中华人民共...
# 6091  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第一款,《中华人民共...
# 6092  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 6093  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条,《中华人民共和国刑...
# 6094  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第一款,《中华人民共...
# 6095  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条,《关于办理环境污染...
# 6096  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第一款,《中华人民共...
# 6097           {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款}
# 6098  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第三百三十八条,《中华人民共和...
# 6099              {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第五十二条}
# 6100  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款,《中华人民共...
# 6101  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第六十七条第三款,《最高人民法...
# 6102  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 6103  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
# 6104                               {《中华人民共和国刑法》第三百三十八条}
# 6105  {《中华人民共和国刑法》第三百三十八条,《最高人民法院、最高人民检察院关于办理环境污染刑事案...
# 6106  {《中华人民共和国刑法》第三百三十八条,《中华人民共和国刑法》第二十五条第一款,《中华人民共...
#
#                                                 parties              case_id  \
# 0     {公诉机关深圳市宝安区人民检察院。,被告人王某，1953年7月1日，住娄底市冷水江市。因涉嫌...  （2015）深宝法龙刑初字第1193号
# 1     {公诉机关深圳市龙岗区人民检察院。,被告人候某某，因本案于2014年6月25日被羁押，同年6...   （2014）深龙法刑初字第3389号
# 2     {公诉机关晋州市人民检察院。,被告人陈某,男,1980年4月7日出生，汉族,群众,中专文化。...    （2017）冀0183刑初197号
# 3                                    {公诉机关浙江省三门县人民检察院。}      （2015）台三刑初字第99号
# 4     {公诉机关福建省龙岩市新罗区人民检察院。,被告人林汉强，男，1968年4月24日出生，汉族，...     （2015）龙新刑初字第791号
# 5     {公诉机关河北省霸州市人民检察院。,被告人李某，群众，户籍所在地：河北省霸州市，现住霸州市。...      （2014）霸刑初字第474号
# 6     {公诉机关湖州市南浔区人民检察院。,被告人黄某甲。因本案于2015年3月3日被刑事拘留，同月...     （2015）湖浔刑初字第388号
# 7                                    {公诉机关河北省永清县人民检察院。}       （2014）永刑初字第26号
# 8                                    {公诉机关浙江省临海市人民检察院。}    （2016）浙1082刑初701号
# 9     {公诉机关德清县人民检察院。,被告人曾阳，男，1974年7月6日生，汉族，江西省铜鼓县人，文...     （2015）湖德刑初字第615号
# 10    {公诉机关浙江省瑞安市人民检察院。,被告单位瑞安宝源化工有限公司。,诉讼代表人胡某。,辩护人...    （2015）温瑞刑初字第1329号
# 11                                   {公诉机关山西省汾阳市人民检察院。}      （2014）汾刑初字第243号
# 12    {原公诉机关浙江省苍南县人民检察院。,上诉人（原审被告人）徐某。因本案于2015年5月8日被...    （2015）浙温刑终字第1904号
# 13    {公诉机关河北省涞源县人民检察院。,被告人王甲，男，1978年6月12日出生，汉族，初中文化...    （2016）冀0630刑初133号
# 14    {公诉机关揭阳市榕城区人民检察院。,被告人周雄钦周某某，男，1952年11月14日出生，汉族...    （2016）粤5202刑初401号
# 15    {公诉机关晋州市人民检察院。,被告人李某，男，1977年6月13日出生，汉族，初中文化，20...      （2018）冀0183刑初8号
# 16    {公诉机关浙江省乐清市人民检察院。,被告单位乐清市永联电工合金有限公司，统一社会信用代码：9...    （2018）浙0382刑初146号
# 17    {公诉机关江苏省常熟市人民检察院。,被告人周某，女，1966年6月3日生，汉族，初中文化，农...   （2016）苏0581刑初1680号
# 18    {公诉机关广东省广州市增城区人民检察院。,被告单位广州市冠铭五金制品有限公司，地址广州市增城...    （2016）粤0183刑初545号
# 19    {公诉机关江苏省江阴市人民检察院。,被告人王品妹，女，1969年1月17日出生于江苏省江阴市...   （2016）苏0281刑初1749号
# 20    {公诉机关河北省永清县人民检察院。,被告人李某，男，汉族，1979年4月9日出生，河南省内乡...     （2017）冀1023刑初65号
# 21    {公诉机关武义县人民检察院。,被告人罗某甲。因涉嫌犯污染环境罪，于2016年1月20日被武义...    （2016）浙0723刑初327号
# 22    {公诉机关广东省海丰县人民检察院。,被告人陈向忠，男，1970年7月24日出生于广东省海丰县...    （2018）粤1521刑初299号
# 23    {公诉机关海盐县人民检察院。,被告人蒉某。因本案于2013年10月9日被海盐县公安局刑事拘留...     （2014）嘉盐刑初字第160号
# 24    {公诉机关浙江省温州市瓯海区人民检察院。,被告人陈某。因本案于2016年2月23日被抓获，同...    （2016）浙0304刑初255号
# 25    {公诉机关台州市路桥区人民检察院。,被告人成某，务工。2015年7月16日因本案被台州市公安...    （2016）浙1004刑初245号
# 26    {公诉机关河北省大名县人民检察院。,被告人乔某某，男，1964年6月24日出生于河北省馆陶县...     (2018)冀0425刑初80号
# 27    {公诉机关河北省博野县人民检察院。,被告人李某甲，性别：&times;&times;。&ti...       （2015）博刑初字第34号
# 28    {公诉机关福建省将乐县人民检察院。,被告人廖建伟，男，1988年4月14日出生于福建省将乐县...      （2018）闽0428刑初2号
# 29    {公诉机关山东省宁津县人民检察院。,被告人李某，河北省东光县。因涉嫌犯污染环境罪，于2016...     （2016）鲁1422刑初74号
# ...                                                 ...                  ...
# 6077  {公诉机关浙江省永康市人民检察院。,被告人邹洪生，男，1974年9月10日出生于福建省连城县...   （2017）浙0784刑初1268号
# 6078  {公诉机关浙江省兰溪市人民检察院。,被告人陈某，兰溪聚源电子科技有限公司股东兼技术指导。因本...     （2015）金兰刑初字第582号
# 6079  {公诉机关河北省承德市双滦区人民检察院。,被告人王某某，男，因涉嫌污染环境罪，于2015年3...      （2015）双滦刑初字第64号
# 6080  {公诉机关浙江省浦江县人民检察院。,被告人陈某甲，农民。因本案于2016年5月28日被浦江县...    （2016）浙0726刑初579号
# 6081                         {公诉机关天津市北辰区人民检察院。,被告人徐XX。}     （2014）辰刑初字第0279号
# 6082  {公诉机关和县人民检察院。,被告人景某，男，1941年1月8日出生于江苏省丹阳市，汉族，小学...    （2017）皖0523刑初241号
# 6083  {公诉机关普宁市人民检察院。,被告人李某，男，公民身份号码×××0316，汉族，广东省揭西县...    （2016）粤5281刑初393号
# 6084  {公诉机关广东省东莞市第一市区人民检察院。,被告人何秀兰，女，1956年8月10日出生，汉族...   （2017）粤1971刑初2818号
# 6085  {公诉机关浙江省温州市瓯海区人民检察院。,被告单位温州市金雕塑钢制品厂，住所地浙江省温州市瓯...    （2016）浙0304刑初894号
# 6086  {公诉机关湖南省茶陵县人民检察院。,被告人蒋茂文，男，汉族，案发前住茶陵县。因违法排放污染物...    （2016）湘0224刑初215号
# 6087  {公诉机关广东省潮州市潮安区人民检察院。,被告人郭泽喜，男，1979年2月19日出生，汉族，...    （2017）粤5103刑初349号
# 6088  {公诉机关上海铁路运输检察院。,被告人赵某某，男，1963年6月25日出生，汉族，户籍所在地...     （2017）沪7101刑初54号
# 6089  {原公诉机关浙江省永嘉县人民检察院。,上诉人（原审被告人）许妙云，男，1961年2月5日出生...      （2017）浙03刑终277号
# 6090  {公诉机关重庆市渝北区人民检察院。,被告人唐仕才，男，1971年2月14日出生于四川省华蓥市...    （2018）渝0112刑初233号
# 6091  {公诉机关山东省武城县人民检察院。,被告人崔某某，男，1961年出生于山东省武城县，居民身份...       （2015）武刑初字第45号
# 6092  {公诉机关浙江省苍南县人民检察院。,被告人蔡启梨，男，1979年6月24日出生于浙江省苍南县...   （2017）浙0327刑初1180号
# 6093  {公诉机关晋州市人民检察院。,被告人马某，群众。2015年3月30日因涉嫌污染环境罪被晋州市...     （2016）冀0183刑初34号
# 6094  {公诉机关河北省博野县人民检察院。,被告人吴某，农民。2015年7月11日因污染环境被行政拘...     （2016）冀0637刑初39号
# 6095  {公诉机关河北省黄骅市人民检察院。,被告人张某某，男，1969年6月11日出生，汉族，初中文...       （2014）黄刑初字第18号
# 6096                                 {公诉机关绍兴市上虞区人民检察院。}    （2015）绍虞刑初字第1099号
# 6097  {公诉机关桐乡市人民检察院。,被告人严某。2014年2月26日因本案被桐乡市公安局刑事拘留，...     （2014）嘉桐刑初字第378号
# 6098  {公诉机关河北省玉田县人民检察院。,被告人李某，男，1985年4月22日出生，汉族，小学文化...  （2017）冀0229刑初220-1号
# 6099  {公诉机关昌乐县人民检察院。,被告人秦某。因涉嫌污染环境罪于2013年11月29日被昌乐县公...       （2015）乐刑初字第77号
# 6100  {公诉机关义乌市人民检察院。,被告人徐某甲。因涉嫌犯污染环境罪于2014年5月10日被义乌市...    （2014）金义刑初字第1892号
# 6101  {公诉机关绍兴市越城区人民检察院。,被告人刘某甲，农民。因涉嫌犯污染环境罪于2014年7月3...    （2014）绍越刑初字第1301号
# 6102  {公诉机关汕头市潮南区人民检察院。,被告人庄某江，男，1953年8月24日出生于广东省汕头市...     （2018）粤0514刑初88号
# 6103  {原公诉机关浙江省永康市人民检察院。,上诉人（原审被告人）夏某甲。2014年5月4日因本案被...    （2014）浙金刑一终字第346号
# 6104  {公诉机关银川市西夏区人民检察院。,被告人张某某，女，1969年3月6日出生于山东省嘉祥县，...      （2015）夏刑初字第224号
# 6105  {公诉机关河北省献县人民检察院。,被告人姚某，农民，群众。因涉嫌污染环境罪于2014年12月...    （2016）冀0929刑初112号
# 6106  {公诉机关溧阳市人民检察院。,被告人张春，男，1970年2月18日生，汉族，溧阳市人，中专文...    （2017）苏0481刑初367号
#
#        type                                           filename case_type_org  \
# 0     刑事判决书   （2015）深宝法龙刑初字第1193号_ab98a37d-b47a-489b-9e9e-d...         刑事案件
# 1     刑事判决书   （2014）深龙法刑初字第3389号_0b406e5f-3f4c-43e6-8b07-bb...         刑事案件
# 2     刑事判决书   （2017）冀0183刑初197号_f76bbb6d-b9ec-4924-84e6-a8b...         刑事案件
# 3     刑事判决书   （2015）台三刑初字第99号_52180afc-3ad0-47a6-b4b6-bd796...         刑事案件
# 4     刑事判决书   （2015）龙新刑初字第791号_23305324-42ba-431e-bd73-cd12...         刑事案件
# 5     刑事判决书   （2014）霸刑初字第474号_440d8e1d-13e6-41cc-ab7d-5d7d6...         刑事案件
# 6     刑事判决书   （2015）湖浔刑初字第388号_cda55bcf-a39e-4356-9c84-1b2e...         刑事案件
# 7     刑事判决书   （2014）永刑初字第26号_7c2ee545-b6e1-4e93-a3fa-b58323...         刑事案件
# 8     刑事判决书   （2016）浙1082刑初701号_c2a1490d-31f1-4114-9b44-48f...         刑事案件
# 9     刑事判决书   （2015）湖德刑初字第615号_b82aff4b-3538-4287-bcc4-a896...         刑事案件
# 10    刑事判决书   （2015）温瑞刑初字第1329号_7cba1d5a-f4e8-4dd2-88e1-c22...         刑事案件
# 11    刑事判决书   （2014）汾刑初字第243号_7c4dbbb9-77cc-4669-94bb-a4628...         刑事案件
# 12    刑事判决书   （2015）浙温刑终字第1904号_b0f4e960-6d4a-4769-a0b3-878...         刑事案件
# 13    刑事判决书   （2016）冀0630刑初133号_241ec099-2a79-45b7-96b8-a71...         刑事案件
# 14    刑事判决书   （2016）粤5202刑初401号_a52488c0-a62e-4aea-830b-4dc...         刑事案件
# 15    刑事判决书   （2018）冀0183刑初8号_8b62ca27-28f9-45d0-a1a2-a8b20...         刑事案件
# 16    刑事判决书   （2018）浙0382刑初146号_3386f7b1-306d-4720-b29e-a8a...         刑事案件
# 17    刑事判决书   （2016）苏0581刑初1680号_b61c2266-a160-4ddc-9512-98...         刑事案件
# 18    刑事判决书   （2016）粤0183刑初545号_a445192b-e6dd-49c7-b4a1-7f3...         刑事案件
# 19    刑事判决书   （2016）苏0281刑初1749号_3c4ed561-4039-42f8-98cc-45...         刑事案件
# 20    刑事判决书   （2017）冀1023刑初65号_7101a29c-cbaa-41b3-a4e0-a813...         刑事案件
# 21    刑事判决书   （2016）浙0723刑初327号_3f6471a6-c08a-46fc-a815-309...         刑事案件
# 22    刑事判决书   （2018）粤1521刑初299号_8a48c890-31c1-4f5e-b818-a91...         刑事案件
# 23    刑事判决书   （2014）嘉盐刑初字第160号_5e9cf726-301e-401f-b0de-85fd...         刑事案件
# 24    刑事判决书   （2016）浙0304刑初255号_3bb1882c-7cac-45c6-975b-5e6...         刑事案件
# 25    刑事判决书   （2016）浙1004刑初245号_cd9724cb-e0f7-4651-bd8b-cdb...         刑事案件
# 26    刑事判决书   （2018）冀0425刑初80号_bdf981f6-6753-4b68-b946-a907...         刑事案件
# 27    刑事判决书   （2015）博刑初字第34号_c9c5e2b4-c2d8-49e9-953f-7fdd60...         刑事案件
# 28    刑事判决书   （2018）闽0428刑初2号_beb385a6-13b7-4fdf-b1f3-a8c50...         刑事案件
# 29    刑事判决书   （2016）鲁1422刑初74号_60b9ccd1-8615-4fe5-ab55-2582...         刑事案件
# ...     ...                                                ...           ...
# 6077  刑事判决书   （2017）浙0784刑初1268号_074235cc-59f3-4f45-be20-a8...         刑事案件
# 6078  刑事判决书   （2015）金兰刑初字第582号_3ef4e754-db32-4f57-ad6c-f71e...         刑事案件
# 6079  刑事判决书   （2015）双滦刑初字第64号_a0241697-64c0-435b-9185-61047...         刑事案件
# 6080  刑事判决书   （2016）浙0726刑初579号_a8bb09f9-b411-44fa-b9f8-0e1...         刑事案件
# 6081  刑事判决书   （2014）辰刑初字第0279号_61bd433e-d997-4217-9f8d-773f...         刑事案件
# 6082  刑事判决书   （2017）皖0523刑初241号_a26b0576-7a5f-4f84-8705-a85...         刑事案件
# 6083  刑事判决书   （2016）粤5281刑初393号_bbed49cf-25be-42a0-b2a0-cb0...         刑事案件
# 6084  刑事判决书   （2017）粤1971刑初2818号_5d3d66c3-66d7-446e-9cf3-a8...         刑事案件
# 6085  刑事判决书   （2016）浙0304刑初894号_3db49d8a-10fe-4dc4-92e8-503...         刑事案件
# 6086  刑事判决书   （2016）湘0224刑初215号_2dbbcf37-5295-4b88-8844-a78...         刑事案件
# 6087  刑事判决书   （2017）粤5103刑初349号_35ce9e78-fb03-419b-92ed-a83...         刑事案件
# 6088  刑事判决书   （2017）沪7101刑初54号_dae6af14-9427-407a-b544-a75a...         刑事案件
# 6089  刑事裁定书   （2017）浙03刑终277号_9f72cec5-9aa2-4643-89c4-a73d0...         刑事案件
# 6090  刑事判决书   （2018）渝0112刑初233号_4bef8536-984b-470e-89f9-a8e...         刑事案件
# 6091  刑事判决书   （2015）武刑初字第45号_b995cc07-d3c9-4369-bfd0-41e1ae...         刑事案件
# 6092  刑事判决书   （2017）浙0327刑初1180号_fa1980f2-cb50-42c5-85ff-a8...         刑事案件
# 6093  刑事判决书   （2016）冀0183刑初34号_9792b2f9-554f-423d-aa85-70fa...         刑事案件
# 6094  刑事判决书   （2016）冀0637刑初39号_67eb35e2-9570-4133-81f9-ed03...         刑事案件
# 6095  刑事判决书   （2014）黄刑初字第18号_9cee5f17-2b7c-4aee-87c8-696ee2...         刑事案件
# 6096  刑事判决书   （2015）绍虞刑初字第1099号_307c8286-aee4-427a-9c53-b62...         刑事案件
# 6097  刑事判决书   （2014）嘉桐刑初字第378号_af9b4a92-7c38-4245-bee2-89a6...         刑事案件
# 6098  刑事判决书   （2017）冀0229刑初220-1号_4b8c5897-56a9-4205-a621-a...         刑事案件
# 6099  刑事判决书   （2015）乐刑初字第77号_6c45fed1-2a57-4283-9cb2-5aa6d6...         刑事案件
# 6100  刑事判决书   （2014）金义刑初字第1892号_5e1bafa4-7e9d-411c-883b-60c...         刑事案件
# 6101  刑事判决书   （2014）绍越刑初字第1301号_3a71e565-5700-4745-acb7-dbc...         刑事案件
# 6102  刑事判决书   （2018）粤0514刑初88号_26bcfade-6a22-47ac-b3db-a8b6...         刑事案件
# 6103  刑事判决书   （2014）浙金刑一终字第346号_72c9668c-8745-450a-9ab1-993...         刑事案件
# 6104  刑事判决书   （2015）夏刑初字第224号_3dd065fb-faff-45e2-b094-5d2aa...         刑事案件
# 6105  刑事判决书   （2016）冀0929刑初112号_b39f18d6-6ebc-4dbd-9be3-ba3...         刑事案件
# 6106  刑事判决书   （2017）苏0481刑初367号_97f8926e-b98a-4b44-95e9-a81...         刑事案件
#
#      province                                       originaltext  \
# 0          广东   王在堂污染环境罪一审刑事判决书\n广东省深圳市宝安区人民法院\n刑 事 判 决 书\n（2...
# 1          广东   侯某某环境污染一审刑事判决书\n广东省深圳市龙岗区人民法院\n刑 事 判 决 书\n（20...
# 2          河北   陈某犯污染环境罪一审刑事判决书\n河北省晋州市人民法院\n\n\n\t刑 事 判 决 书\...
# 3          浙江   赵某、蔡某犯污染环境罪一审刑事判决书\n浙江省三门县人民法院\n刑 事 判 决 书\n（2...
# 4          福建   林汉强、陈某甲等犯污染环境罪一审刑事判决书\n福建省龙岩市新罗区人民法院\n刑 事 判 决...
# 5          河北   李某污染环境罪一审刑事判决书\n河北省霸州市人民法院\n刑 事 判 决 书\n（2014）...
# 6          浙江   黄某甲、黄某乙犯污染环境罪一审刑事判决书\n浙江省湖州市南浔区人民法院\n刑 事 判 决 ...
# 7          河北   陈某甲污染环境罪一审刑事判决书\n河北省永清县人民法院\n刑 事 判 决 书\n（2014...
# 8          浙江   梁某、朱某甲犯污染环境罪一审刑事判决书\n浙江省临海市人民法院\n刑 事 判 决 书\n（...
# 9          浙江   曾阳、张海修等污染环境罪一审刑事判决书\n浙江省德清县人民法院\n刑 事 判 决 书\n（...
# 10         浙江   瑞安宝源化工有限公司、林文弟等犯污染环境罪一审刑事判决书\n浙江省瑞安市人民法院\n刑 事...
# 11         山西   宋某、蔚某犯污染环境罪一审刑事判决书\n山西省汾阳市人民法院\n刑 事 判 决 书\n（2...
# 12         浙江   徐某犯污染环境罪二审刑事判决书\n浙江省温州市中级人民法院\n刑 事 判 决 书\n（20...
# 13         河北   王甲犯污染环境罪一审刑事判决书\n<p>\n\t<title></title>\n</p>...
# 14         广东   周雄钦周某某污染环境一审刑事判决书\n广东省揭阳市榕城区人民法院\n刑 事 判 决 书\n...
# 15         河北   李某、贾某犯污染环境罪一审刑事判决书\n河北省晋州市人民法院\n\n\n\t刑 事 判 决...
# 16         浙江   乐清市永联电工合金有限公司、韩梅涛污染环境一审刑事判决书\n浙江省乐清市人民法院\n\n\...
# 17         江苏   周某犯污染环境罪一审刑事判决书\n<p>\n\t<title></title>\n</p>...
# 18         广东   广州市冠铭五金制品有限公司与刘永志污染环境罪2016刑初545一审刑事判决书\n广东省广州...
# 19         江苏   王品妹犯污染环境罪一审刑事判决书\n江苏省江阴市人民法院\n刑 事 判 决 书\n（201...
# 20         河北   李某、周某污染环境一审刑事判决书\n河北省永清县人民法院\n刑 事 判 决 书\n（201...
# 21         浙江   罗某甲犯污染环境罪一审刑事判决书\n浙江省武义县人民法院\n刑 事 判 决 书\n（201...
# 22         广东   陈向忠污染环境一审刑事判决书\n广东省海丰县人民法院\n刑 事 判 决 书\n（2018）...
# 23         浙江   蒉某、陆某污染环境罪一审刑事判决书\n浙江省海盐县人民法院\n刑 事 判 决 书\n（20...
# 24         浙江   陈某犯污染环境罪一审刑事判决书\n浙江省温州市瓯海区人民法院\n刑 事 判 决 书\n（2...
# 25         浙江   成某犯污染环境罪一审刑事判决书\n浙江省台州市路桥区人民法院\n刑 事 判 决 书\n（2...
# 26         河北   乔某某污染环境一审刑事判决书\n河北省大名县人民法院\n刑 事 判 决 书\n(2018)...
# 27         河北   李某甲犯污染环境罪一审刑事判决书\n河北省博野县人民法院\n\n\n\t刑 事 判 决 书...
# 28         福建   廖建伟污染环境一审刑事判决书\n福建省将乐县人民法院\n\n\n\t刑 事 判 决 书\n...
# 29         山东   李某犯污染环境罪一审刑事判决书\n山东省宁津县人民法院\n刑 事 判 决 书\n（2016...
# ...       ...                                                ...
# 6077       浙江   邹洪生、胡梦江等污染环境罪一审刑事判决书\n浙江省永康市人民法院\n刑 事 判 决 书\n...
# 6078       浙江   陈某、童某等犯污染环境罪一审刑事判决书\n浙江省兰溪市人民法院\n刑 事 判 决 书\n（...
# 6079       河北   被告人王某某污染环境罪一审刑事判决书\n河北省承德市双滦区人民法院\n刑 事 判 决 书\...
# 6080       浙江   陈某甲、陈某乙犯污染环境罪一审刑事判决书\n浙江省浦江县人民法院\n刑 事 判 决 书\n...
# 6081       天津   徐XX污染环境一审刑事判决书\n天津市北辰区人民法院\n刑 事 判 决 书\n（2014）...
# 6082       安徽   景某污染环境罪一审刑事判决书\n<p>\n\t<title></title>\n</p>\...
# 6083       广东   李某污染环境一审刑事判决书\n广东省普宁市人民法院\n刑 事 判 决 书\n（2016）粤...
# 6084       广东   何秀兰污染环境一审刑事判决书\n广东省东莞市第一人民法院\n刑 事 判 决 书\n（201...
# 6085       浙江   丁洪友、林金生污染环境罪一审刑事判决书\n浙江省温州市瓯海区人民法院\n刑 事 判 决 书...
# 6086       湖南   蒋茂文污染环境罪一审刑事判决书\n湖南省茶陵县人民法院\n\n\n\t刑 事 判 决 书\...
# 6087       广东   郭泽喜、李明和污染环境一审刑事判决书\n广东省潮州市潮安区人民法院\n刑 事 判 决 书\...
# 6088       上海   赵某某污染环境一审刑事判决书\n上海铁路运输法院\n刑 事 判 决 书\n（2017）沪7...
# 6089       浙江   许妙云、胡忠考污染环境二审刑事裁定书\n浙江省温州市中级人民法院\n刑 事 裁 定 书\n...
# 6090       重庆   唐仕才污染环境一审刑事判决书\n<p>\n\t<title></title>\n</p>\...
# 6091       山东   被告人崔凤杰犯污染环境罪一审刑事判决书\n山东省武城县人民法院\n刑 事 判 决 书\n（...
# 6092       浙江   蔡启梨污染环境罪一审刑事判决书\n浙江省苍南县人民法院\n刑 事 判 决 书\n（2017...
# 6093       河北   马某犯污染环境罪一审刑事判决书\n河北省晋州市人民法院\n刑 事 判 决 书\n（2016...
# 6094       河北   吴某污染环境一审刑事判决书\n河北省博野县人民法院\n刑 事 判 决 书\n（2016）冀...
# 6095       河北   张某某污染环境一审刑事判决书\n河北省黄骅市人民法院\n刑 事 判 决 书\n（2014）...
# 6096       浙江   沈某、熊某犯污染环境罪一审刑事判决书\n绍兴市上虞区人民法院\n刑 事 判 决 书\n（2...
# 6097       浙江   严某污染环境罪一审刑事判决书\n浙江省桐乡市人民法院\n刑 事 判 决 书\n（2014）...
# 6098       河北   河北省玉田县人民检察院与李某污染环境罪一审刑事判决书\n<style type="text...
# 6099       山东   秦某、傅某甲犯污染环境罪一审刑事判决书\n山东省昌乐县人民法院\n刑 事 判 决 书\n（...
# 6100       浙江   徐某甲污染环境罪一审刑事判决书\n浙江省义乌市人民法院\n刑 事 判 决 书\n（2014...
# 6101       浙江   刘某甲犯污染环境罪一审刑事判决书\n浙江省绍兴市越城区人民法院\n刑 事 判 决 书\n（...
# 6102       广东   庄某江污染环境一审刑事判决书\n汕头市潮南区人民法院\n刑 事 判 决 书\n（2018）...
# 6103       浙江   夏某甲、夏某乙污染环境罪二审刑事判决书\n浙江省金华市中级人民法院\n刑 事 判 决 书\...
# 6104       宁夏   张某某污染环境罪一审刑事判决书\n宁夏回族自治区银川市西夏区人民法院\n刑 事 判 决 书...
# 6105       河北   姚某污染环境一审刑事判决书\n河北省献县人民法院\n刑 事 判 决 书\n（2016）冀0...
# 6106       江苏   张春、黄耀平污染环境罪一审刑事判决书\n江苏省溧阳市人民法院\n刑 事 判 决 书\n（2...
#
#                                           segmentedtext
# 0       王在堂 污染 环境 罪 一审 刑事 判决书 广东省 深圳市 宝安区 人民法院 刑 事 判...
# 1       侯某某 环境污染 一审 刑事 判决书 广东省 深圳市 龙岗区 人民法院 刑 事 判 决 ...
# 2       陈某 犯 污染 环境 罪 一审 刑事 判决书 河北省 晋州市 人民法院 \t 刑 事 判...
# 3       赵某 蔡某 犯 污染 环境 罪 一审 刑事 判决书 浙江省 三门县 人民法院 刑 事 判...
# 4       林汉强 陈某 甲等 犯 污染 环境 罪 一审 刑事 判决书 福建省 龙岩市新罗区人民法院...
# 5       李某 污染 环境 罪 一审 刑事 判决书 河北省 霸州市 人民法院 刑 事 判 决 书 ...
# 6       黄某甲 黄某乙 犯 污染 环境 罪 一审 刑事 判决书 浙江省 湖州市 南浔区 人民法院...
# 7       陈某 甲 污染 环境 罪 一审 刑事 判决书 河北省 永清县 人民法院 刑 事 判 决 ...
# 8       梁某 朱 某甲 犯 污染 环境 罪 一审 刑事 判决书 浙江省 临海市 人民法院 刑 事...
# 9       曾阳 张海修 等 污染 环境 罪 一审 刑事 判决书 浙江省 德清县 人民法院 刑 事 ...
# 10      瑞安宝源化工有限公司 林文弟 等 犯 污染 环境 罪 一审 刑事 判决书 浙江省 瑞安市...
# 11      宋某 蔚某 犯 污染 环境 罪 一审 刑事 判决书 山西省 汾阳市 人民法院 刑 事 判...
# 12      徐某 犯 污染 环境 罪 二审 刑事 判决书 浙江省 温州市 中级 人民法院 刑 事 判...
# 13      王甲 犯 污染 环境 罪 一审 刑事 判决书 <p> \t<title>< title>...
# 14      周雄钦 周某某 污染 环境 一审 刑事 判决书 广东省 揭阳市榕城区人民法院 刑 事 判...
# 15      李某 贾某 犯 污染 环境 罪 一审 刑事 判决书 河北省 晋州市 人民法院 \t 刑 ...
# 16      乐清市永联电工合金有限公司 韩梅涛 污染 环境 一审 刑事 判决书 浙江省 乐清市 人民...
# 17      周某 犯 污染 环境 罪 一审 刑事 判决书 <p> \t<title>< title>...
# 18      广州市冠铭五金制品有限公司 与 刘永志 污染 环境 罪 2016 刑初 545 一审 刑...
# 19      王品妹 犯 污染 环境 罪 一审 刑事 判决书 江苏省 江阴市 人民法院 刑 事 判 决...
# 20      李某 周某 污染 环境 一审 刑事 判决书 河北省 永清县 人民法院 刑 事 判 决 书...
# 21      罗 某甲 犯 污染 环境 罪 一审 刑事 判决书 浙江省 武义县 人民法院 刑 事 判 ...
# 22      陈向忠 污染 环境 一审 刑事 判决书 广东省 海丰县 人民法院 刑 事 判 决 书 2...
# 23      蒉 某 陆某 污染 环境 罪 一审 刑事 判决书 浙江省 海盐县 人民法院 刑 事 判 ...
# 24      陈某 犯 污染 环境 罪 一审 刑事 判决书 浙江省 温州市瓯海区人民法院 刑 事 判 ...
# 25      成 某 犯 污染 环境 罪 一审 刑事 判决书 浙江省 台州市路桥区人民法院 刑 事 判...
# 26      乔某某 污染 环境 一审 刑事 判决书 河北省 大名县 人民法院 刑 事 判 决 书 2...
# 27      李 某甲 犯 污染 环境 罪 一审 刑事 判决书 河北省 博野县 人民法院 \t 刑 事...
# 28      廖建伟 污染 环境 一审 刑事 判决书 福建省 将乐县人民法院 \t 刑 事 判 决 书...
# 29      李某 犯 污染 环境 罪 一审 刑事 判决书 山东省 宁津县 人民法院 刑 事 判 决 ...
# ...                                                 ...
# 6077    邹洪生 胡梦江 等 污染 环境 罪 一审 刑事 判决书 浙江省 永康市 人民法院 刑 事...
# 6078    陈某 童某 等 犯 污染 环境 罪 一审 刑事 判决书 浙江省 兰溪市 人民法院 刑 事...
# 6079    被告人 王某某 污染 环境 罪 一审 刑事 判决书 河北省 承德市双滦区人民法院 刑 事...
# 6080    陈某 甲 陈某乙 犯 污染 环境 罪 一审 刑事 判决书 浙江省 浦江县 人民法院 刑 ...
# 6081    徐 XX 污染 环境 一审 刑事 判决书 天津市 北辰区 人民法院 刑 事 判 决 书 ...
# 6082    景某 污染 环境 罪 一审 刑事 判决书 <p> \t<title>< title> <...
# 6083    李某 污染 环境 一审 刑事 判决书 广东省 普宁市 人民法院 刑 事 判 决 书 20...
# 6084    何秀兰 污染 环境 一审 刑事 判决书 广东省 东莞市 第一 人民法院 刑 事 判 决 ...
# 6085    丁洪友 林金生 污染 环境 罪 一审 刑事 判决书 浙江省 温州市瓯海区人民法院 刑 事...
# 6086    蒋茂文 污染 环境 罪 一审 刑事 判决书 湖南省 茶陵县 人民法院 \t 刑 事 判 ...
# 6087    郭泽喜 李明 和 污染 环境 一审 刑事 判决书 广东省 潮州市 潮安区 人民法院 刑 ...
# 6088    赵某某 污染 环境 一审 刑事 判决书 上海 铁路运输法院 刑 事 判 决 书 2017...
# 6089    许妙云 胡忠考 污染 环境 二审 刑事 裁定书 浙江省 温州市 中级 人民法院 刑 事 ...
# 6090    唐仕才 污染 环境 一审 刑事 判决书 <p> \t<title>< title> < ...
# 6091    被告人 崔凤杰 犯 污染 环境 罪 一审 刑事 判决书 山东省 武城县 人民法院 刑 事...
# 6092    蔡启梨 污染 环境 罪 一审 刑事 判决书 浙江省 苍南县 人民法院 刑 事 判 决 书...
# 6093    马某 犯 污染 环境 罪 一审 刑事 判决书 河北省 晋州市 人民法院 刑 事 判 决 ...
# 6094    吴某 污染 环境 一审 刑事 判决书 河北省 博野县 人民法院 刑 事 判 决 书 20...
# 6095    张某某 污染 环境 一审 刑事 判决书 河北省 黄骅市 人民法院 刑 事 判 决 书 2...
# 6096    沈某 熊某 犯 污染 环境 罪 一审 刑事 判决书 绍兴市 上虞区人民法院 刑 事 判 ...
# 6097    严某 污染 环境 罪 一审 刑事 判决书 浙江省 桐乡市 人民法院 刑 事 判 决 书 ...
# 6098    河北省玉田县人民检察院 与 李某 污染 环境 罪 一审 刑事 判决书 <style ty...
# 6099    秦某 傅 某甲 犯 污染 环境 罪 一审 刑事 判决书 山东省 昌乐县 人民法院 刑 事...
# 6100    徐 某甲 污染 环境 罪 一审 刑事 判决书 浙江省 义乌市 人民法院 刑 事 判 决 ...
# 6101    刘 某甲 犯 污染 环境 罪 一审 刑事 判决书 浙江省 绍兴市越城区人民法院 刑 事 ...
# 6102    庄 某江 污染 环境 一审 刑事 判决书 汕头市 潮南区 人民法院 刑 事 判 决 书 ...
# 6103    夏 某甲 夏某 乙 污染 环境 罪 二审 刑事 判决书 浙江省 金华市 中级 人民法院 ...
# 6104    张某某 污染 环境 罪 一审 刑事 判决书 宁夏 回族 自治区银川市西夏区人民法院 刑 ...
# 6105    姚某 污染 环境 一审 刑事 判决书 河北省 献县 人民法院 刑 事 判 决 书 201...
# 6106    张春 黄耀平 污染 环境 罪 一审 刑事 判决书 江苏省 溧阳市 人民法院 刑 事 判 ...
#
# [6107 rows x 30 columns]

# %%
pollution_df["originaltext"][735]
# Out:
# ' 孙某、李某等犯污染环境罪一审刑事判决书\n江苏省宜兴市人民法院\n\n\n\t刑 事 判 决 书\n\n\n\t(2015)宜环刑初字第2号\n\n\n\t公诉机关宜兴市人民检察院。\n\n\n\t被告人孙某，个体运输。\n\n\n\t因本案于2015年9月14日被宜兴市公安局刑事拘留，同年10月14日被取保候审，2015年12月14日被本院决定取保候审，2016年5月27日被本院决定逮捕，5月30日被宜兴市公安局执行逮捕。现羁押于宜兴市看守所。\n\n\n\t被告人李某，无业。\n\n\n\t因本案于2015年9月14日被宜兴市公安局取保候审，2016年12月14日被本院决定取保候审，2016年5月27日被本院决定逮捕，5月30日被宜兴市公安局执行逮捕。现羁押于宜兴市看守所。被告人王某甲，无业。因本案于2015年10月20日被宜兴市公安局取保候审，2016年12月14日被本院决定取保候审，2016年5月27日被本院决定逮捕，5月30日被宜兴市公安局执行逮捕。现羁押于宜兴市看守所。\n\n\n\t宜兴市人民检察院以宜检诉刑诉（2015）1415号起诉书指控被告人孙某、李某、王某甲犯污染环境罪，于2015年12月14日以简易程序向本院提起公诉。本院受理后，认为该案案情复杂，于2016年1月27日变更为普通程序审理，并依法组成合议庭，于2016年5月4日公开开庭审理了本案。宜兴市人民检察院指派检察员尹志亚出庭支持公诉，被告人孙某、李某、王某甲到庭参加诉讼。本案经依法延长审限，现已审理终结。经审理查明，2015年4月18日，被告人孙某为赚取运费，在没有处置化工废料资质的情况下，伙同被告人李某、王某甲，驾驶其农用车，将马某存放在宜兴市苏泰化工物资经营部内的21桶化工废料运至宜兴市宜漕公路与文庄路交汇处加油站东侧空地上，随意倾倒、处置。案发后，公安侦查人员在该处查获装有化工废料的铁桶21只，共计4.449吨。经鉴定，上述化工废料（含包装桶）属于危险废物。案发后，被告人孙某、李某、王某甲接公安民警电话通知后，主动至公安机关接受调查，并如实供述了上述事实。本案审理中，宜兴市人民检察院向本院提起附带民事诉讼，要求被告人孙某、李某、王某甲与马祖洪承担本案中危险废物鉴定费用、处置及相关人工费用等合计人民币94860元。经本院主持调解，马祖洪表示愿意全部承担，上述款项已于2016年5月4日全部支付。上述事实，被告人孙某、李某、王某甲在开庭审理过程中亦无异议，且有共同行为人马某的供述笔录，证人王某乙、周某、邵某、王某丙等人的证言笔录，辨认笔录，宜兴市公安局现场笔录、现场勘验笔录、摄影照片，上海化工研究院检测中心出具的检验报告，江苏省环境科学学会出具的污染环境案危险废物特性技术评估意见，江苏省宜兴市人民检察院刑事附带民事起诉书，本院制作的调解笔录、江苏省暂扣款专用收据，公安侦查人员出具的刑事案件侦破经过材料等证据予以证实，足以认定。本院认为，被告人孙某、李某、王某甲在没有处置化工废料资质的情况下，随意倾倒、处置危险废物4.449吨，严重污染环境，其行为均已构成污染环境罪，应予惩处。宜兴市人民检察院指控的罪名成立，予以采纳。在共同犯罪中，被告人孙某积极组织实施犯罪，起主要作用，系主犯，应当按照其所参与的全部犯罪处罚；被告人李某、王某甲帮助他人实施犯罪，起次要作用，系从犯，依法予以从轻处罚。被告人孙某、李某、王某甲能主动向公安机关投案，归案后能如实供述自己的犯罪事实，是自首，依法予以从轻处罚。被告人孙某、李某、王某甲在庭审中能自愿认罪，予以从轻处罚。据此，依照《中华人民共和国刑法》第三百三十八条，第二十五条第一款，第二十六条第一款、第四款，第二十七条，第六十七条第一款的规定，判决如下：一、被告人孙某犯污染环境罪，判处有期徒刑六个月（刑期从判决执行之日起计算。判决执行前先行羁押的，羁押一日折抵刑期一日，即自2016年5月30日起至2016年10月29日止），并处罚金人民币八千元（罚金于本判决发生法律效力第二日起三十日内缴纳）。二、被告人李某犯污染环境罪，判处拘役四个月（刑期从判决执行之日起计算。判决执行前先行羁押的，羁押一日折抵刑期一日，即自2016年5月30日起至2016年9月29日止），并处罚金人民币五千元（罚金于本判决发生法律效力第二日起三十日内缴纳）。三、被告人王某甲犯污染环境罪，判处拘役四个月（刑期从判决执行之日起计算。判决执行前先行羁押的，羁押一日折抵刑期一日，即自2016年5月30日起至2016年9月29日止），并处罚金人民币五千元（罚金于本判决发生法律效力第二日起三十日内缴纳）。如不服本判决，可在接到本判决书的第二日起十日内，通过本院或者直接向江苏省无锡市中级人民法院提出上诉。书面上诉的，应提交上诉状正本一份，副本二份。\n\n\n\t审\u3000判\u3000长\u3000\u3000蒋毅斌\n\n\n\t审\u3000判\u3000员\u3000\u3000王兴鹤\n\n\n\t人民陪审员\u3000\u3000陈法林\n\n\n\t二〇一六年五月二十七日\n\n\n\t书\u3000记\u3000员\u3000\u3000倪\u3000臻\n\n\n\t本案援引法律条款《中华人民共和国刑法》：第三百三十八条违反国家规定，排放、倾倒或者处置有放射性的废物、含传染病病原体的废物、有毒物质或者其他有害物质，严重污染环境的，处三年以下有期徒刑或者拘役，并处或者单处罚金；后果特别严重的，处三年以上七年以下有期徒刑，并处罚金。第二十五条第一款共同犯罪是指两人以上共同故意犯罪。第二十六条第一款、第四款组织、领导犯罪集团进行犯罪活动的或者在共同犯罪中起主要作用的，是主犯。对于第三款规定以外的主犯，应当按照其所参与的或者组织、指挥的全部犯罪处罚。第二十七条在共同犯罪中起次要或者辅助作用的，是从犯。对于从犯，应当从轻、减轻处罚或者免除处罚。第六十七条第一款犯罪以后自动投案，如实供述自己的罪行的，是自首。对于自首的犯罪分子，可以从轻或者减轻处罚。其中，犯罪较轻的，可以免除处罚。\n '

# %%
pollution_df["decision"][735]
# Out:
# '[" "]'

# %%
k = []
for i in unique_case:
    test = pollution_df["decision"][i]
    if ("维持" not in test) and ("驳回" not in test) and ("撤销" not in test):
        k.append(i)
    #print(test)
print(k)
# Out:
# [57, 204, 735, 962, 1045, 1437, 1523, 1618, 1758, 1996, 2039, 2122, 2421, 2508, 2627, 2630, 2672, 2765, 3224, 3432, 3560, 4037, 4190, 4344, 5006, 5088, 5688, 5734, 5880]

# %%
# find average length of the decision column
sum(pollution_df["decision"].apply(len))/len(pollution_df["decision"])
# Out:
# 281.6991976420501

# %%
def clean_penalties_without_delete(sentence):
    def find_penalties(decision):
        decision_dic = {}
        if ("被告" in decision):
            sentence = HanLP.segment(decision)
            find_lst = {"被告人":True, "单位":True, "有期徒刑":True, "罚金":True, 
                        "缓刑":True, "羁押":True, "拘役":True}
            for i in range(len(sentence)):
                # ignore special words (维持，驳回，撤销)
                if (sentence.get(i).word == "单位") and (find_lst["单位"]):
                    find_lst, decision_dic = extract_penalties(sentence, "被告单位", i, decision_dic, "v", find_lst)
                if (sentence.get(i).word == "被告人") and (find_lst["被告人"]):
                    find_lst, decision_dic = extract_penalties(sentence, "被告人", i, decision_dic, "v", find_lst)
                if (sentence.get(i).word == "有期徒刑") and (find_lst["有期徒刑"]):
                    find_lst, decision_dic = extract_penalties(sentence, "有期徒刑", i, decision_dic, "w", find_lst)
                if (sentence.get(i).word == "罚金") and (find_lst["罚金"]):
                    find_lst, decision_dic = extract_penalties(sentence, "罚金", i, decision_dic, "w", find_lst)
                if (sentence.get(i).word == "处罚金") and (find_lst["罚金"]):
                    find_lst, decision_dic = extract_penalties(sentence, "处罚金", i, decision_dic, "w", find_lst)
                if (sentence.get(i).word == "缓刑") and (find_lst["缓刑"]):
                    find_lst, decision_dic = extract_penalties(sentence, "缓刑", i, decision_dic, "w", find_lst)    
                if (sentence.get(i).word == "羁押") and (find_lst["羁押"]):
                    find_lst, decision_dic = extract_penalties(sentence, "羁押", i, decision_dic, "w", find_lst)    
                if (sentence.get(i).word == "拘役") and (find_lst["拘役"]):
                    find_lst, decision_dic = extract_penalties(sentence, "拘役", i, decision_dic, "w", find_lst)    
        return decision_dic
    
    sentence_lst = sentence.split(",")
    penalties = []
    for i in sentence_lst:
        p = find_penalties(i)
        if len(p) > 1:
            penalties.append(p)
    return penalties

def find_penalties(decision):
        decision_dic = {}
        if ("被告" in decision):
            sentence = HanLP.segment(decision)
            find_lst = {"被告人":True, "单位":True, "有期徒刑":True, "罚金":True, 
                        "缓刑":True, "羁押":True, "拘役":True}
            for i in range(len(sentence)):
                # ignore special words (维持，驳回，撤销)
#                 print(sentence.get(i).word)
#                 print(find_lst)
#                 print(decision_dic)
                if (sentence.get(i).word == "单位") and (find_lst["单位"]):
                    find_lst, decision_dic = extract_penalties(sentence, "被告单位", i, decision_dic, "v", find_lst)
                if (sentence.get(i).word == "被告人") and (find_lst["被告人"]):
                    find_lst, decision_dic = extract_penalties(sentence, "被告人", i, decision_dic, "v", find_lst)
                if (sentence.get(i).word == "有期徒刑") and (find_lst["有期徒刑"]):
                    find_lst, decision_dic = extract_penalties(sentence, "有期徒刑", i, decision_dic, "w", find_lst)
                if (sentence.get(i).word == "处罚金") and (find_lst["罚金"]):
                    find_lst, decision_dic = extract_penalties(sentence, "处罚金", i, decision_dic, "w", find_lst)
                if (sentence.get(i).word == "罚金") and (find_lst["罚金"]):
                    find_lst, decision_dic = extract_penalties(sentence, "罚金", i, decision_dic, "w", find_lst)
                if (sentence.get(i).word == "缓刑") and (find_lst["缓刑"]):
                    find_lst, decision_dic = extract_penalties(sentence, "缓刑", i, decision_dic, "w", find_lst)    
                if (sentence.get(i).word == "羁押") and (find_lst["羁押"]):
                    find_lst, decision_dic = extract_penalties(sentence, "羁押", i, decision_dic, "w", find_lst)    
                if (sentence.get(i).word == "拘役") and (find_lst["拘役"]):
                    find_lst, decision_dic = extract_penalties(sentence, "拘役", i, decision_dic, "w", find_lst)    
        return decision_dic

# %%
#test = pollution_df["originaltext"][37]
test = pollution_df["decision"][53]
print(test)
#print("被告" in test)
if ("维持" in test) or ("驳回" in test) or ("撤销" in test):
        print("unique")
sentence = HanLP.segment(test)
print(sentence)
#print(clean_penalties_without_delete(test))



sentence_lst = test.split("。")
penalties = []
print(sentence_lst)
for i in sentence_lst:
    p = find_penalties(i)
    if len(p) > 1:
        penalties.append(p)
        #print("add")
penalties
# Out:
# [" 被告人袁平犯污染环境罪，判处有期徒刑十个月,并处罚金人民币一万元。", "(刑期从判决执行之日起计算，判决执行以前先行羁押的，羁押一日折抵刑期一日，即自2016年7月7日起至2017年5月6日止。罚金限于本判决生效之日起三十日内缴纳，逾期则强制缴纳。)", "如不服本判决，可在接到判决书的第二日起十日内，通过本院或者直接向四川省成都市中级人民法院提出上诉。书面上诉的，应提交上诉状正本一份，副本二份。"]
# [["/w,  /w, 被告人/n, 袁平/nr, 犯/v, 污染/vn, 环境/n, 罪/n, ，/w, 判处/v, 有期徒刑/n, 十/m, 个/q, 月/n, ,/w, 并处/v, 罚金/n, 人民币/n, 一/m, 万元/q, 。/w, ",/w,  /w, "(/w, 刑期/n, 从/p, 判决/vn, 执行/v, 之日起/ns, 计算/v, ，/w, 判决/vn, 执行/v, 以前/f, 先行/vi, 羁押/v, 的/ude1, ，/w, 羁押/v, 一/m, 日/b, 折抵/nz, 刑期/n, 一/m, 日/b, ，/w, 即/v, 自/p, 2016/m, 年/qt, 7月/t, 7/m, 日/b, 起至/v, 2017/m, 年/qt, 5月/t, 6/m, 日/b, 止/v, 。/w, 罚金/n, 限于/v, 本/rz, 判决/vn, 生效/vi, 之日起/ns, 三十/m, 日内/t, 缴纳/v, ，/w, 逾期/vi, 则/d, 强制/vd, 缴纳/v, 。/w, )",/w,  /w, "/w, 如/v, 不服/v, 本/rz, 判决/vn, ，/w, 可/v, 在/p, 接到/v, 判决书/n, 的/ude1, 第二/mq, 日/b, 起/vf, 十/m, 日内/t, ，/w, 通过/p, 本院/n, 或者/c, 直接/ad, 向/p, 四川省成都市中级人民法院/nt, 提出/v, 上诉/vn, 。/w, 书面/b, 上诉/vn, 的/ude1, ，/w, 应/v, 提交/v, 上诉状/n, 正本/n, 一/m, 份/q, ，/w, 副本/n, 二份/nz, 。/w, "]/w]
# ['[" 被告人袁平犯污染环境罪，判处有期徒刑十个月,并处罚金人民币一万元', '", "(刑期从判决执行之日起计算，判决执行以前先行羁押的，羁押一日折抵刑期一日，即自2016年7月7日起至2017年5月6日止', '罚金限于本判决生效之日起三十日内缴纳，逾期则强制缴纳', ')", "如不服本判决，可在接到判决书的第二日起十日内，通过本院或者直接向四川省成都市中级人民法院提出上诉', '书面上诉的，应提交上诉状正本一份，副本二份', '"]']
# [{'被告人': '袁平', '有期徒刑': '十个月', '罚金': '人民币一万元'}]

# %%
for i in unique_case:

# %%
def recurrence_count(df, column):
    count = 0
    past = []
    for i in range(df.shape[0]):
        n = decision_df.loc[i, column]
        if n not in past:
            past += [n]
        else:
            count += 1
    return count

# %%
print(
"pid count:  " + str(recurrence_count(decision_df, "pid")),
"case count:  " + str(recurrence_count(decision_df, "case_number_id")),
"title count:  " + str(recurrence_count(decision_df, "title"))
)
# Out:
# pid count:  0 case count:  4383 title count:  1358

# %%
# group by case_number_id
case_decision = decision_df.loc[:,["case_number_id"]]
group_by_case = case_decision.groupby(["case_number_id"]).size().reset_index()
group_by_case.columns = ['case_number_id', "count"]

# %%
group_by_case
# Out:
#      case_number_id  count
# 0             00001      9
# 1             00002      8
# 2             00003      6
# 3             00004      6
# 4             00005      4
# 5             00006      3
# 6             00007      1
# 7             00008      2
# 8             00009      4
# 9              0001      9
# 10            00010      2
# 11            00011      1
# 12            00012      1
# 13            00015      1
# 14            00019      1
# 15           000197      1
# 16             0002      5
# 17            00020      1
# 18            00021      1
# 19            00022      1
# 20            00023      3
# 21            00024      2
# 22            00025      1
# 23            00026      1
# 24            00027      1
# 25             0003      4
# 26            00032      1
# 27            00033      1
# 28            00034      3
# 29            00036      2
# ...             ...    ...
# 1693            955      2
# 1694            956      5
# 1695            957      4
# 1696            959      1
# 1697             96     17
# 1698            960      2
# 1699            961      3
# 1700            962      2
# 1701            965      3
# 1702            966      1
# 1703            967      2
# 1704            968      1
# 1705             97     10
# 1706            972      1
# 1707            978      1
# 1708             98      5
# 1709            982      1
# 1710            983      3
# 1711            984      1
# 1712            985      1
# 1713            987      1
# 1714            989      1
# 1715             99      9
# 1716            990      1
# 1717            992      1
# 1718            993      1
# 1719            994      2
# 1720            995      1
# 1721            997      1
# 1722            998      6
#
# [1723 rows x 2 columns]

# %%
# save as dict, if same case id 

case_dict = {}

for i in range(decision_df.shape[0]):
    case_number = decision_df.loc[i, "case_number_id"]
    case_decision = decision_df.loc[i, "decision"]
    if case_number in case_dict:
        case_dict[case_number] += [case_decision]
    else:
        case_dict[case_number] = [case_decision]
